# %% [markdown]
# #Jaeoh Shin, Feb. 28th, 2023
# Deep learning project using Keras.
# Logistic regression model, i.e., predict whether the output is 0 or 1

# %%
#import necessary libraries

from numpy import loadtxt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

from sklearn import metrics
from sklearn.model_selection import train_test_split
# Out:
# 2023-02-28 18:07:31.658744: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-28 18:07:31.836852: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-02-28 18:07:31.836872: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# ...

# %%
df = loadtxt('pima-indians-diabetes.data.csv', delimiter=',')

# %%
X = df[:,0:8]
y = df[:,8]

# %% [markdown]
# Define DL model

# %%
##Two hidden layers with 12 and 8 

def my_model():
    model = Sequential()
    model.add(Dense(12, input_shape=(8,), activation = 'relu'))
    model.add(Dense(8, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(optimizer = 'adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %% [markdown]
# Fit the model with test data

# %%
model = my_model()
model.fit(X, y, epochs=500)
# Out:
# Epoch 1/500
# 24/24 [==============================] - 1s 2ms/step - loss: 62.8743 - accuracy: 0.3490
# Epoch 2/500
# 24/24 [==============================] - 0s 3ms/step - loss: 38.1821 - accuracy: 0.3490
# Epoch 3/500
# 24/24 [==============================] - 0s 3ms/step - loss: 18.5672 - accuracy: 0.3490
# Epoch 4/500
# 24/24 [==============================] - 0s 3ms/step - loss: 5.4221 - accuracy: 0.4206
# Epoch 5/500
# 24/24 [==============================] - 0s 2ms/step - loss: 2.4048 - accuracy: 0.5234
# Epoch 6/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.9557 - accuracy: 0.5052
# Epoch 7/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.6175 - accuracy: 0.5130
# Epoch 8/500
# 24/24 [==============================] - 0s 3ms/step - loss: 1.2685 - accuracy: 0.5065
# Epoch 9/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0315 - accuracy: 0.5573
# Epoch 10/500
# ...

# %%
_, accuracy = model.evaluate(X, y)
print('Accuracy: %.2f' %(accuracy*100))
# Out:
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4533 - accuracy: 0.7799
# Accuracy: 77.99
